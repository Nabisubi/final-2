# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dataset = pd.read_csv(r'C:\Users\acer\Desktop\Bootcamp\credit\loan.csv')
# Out:
# C:\Users\acer\anaconda3\envs\newenv\lib\site-packages\IPython\core\interactiveshell.py:3441: DtypeWarning: Columns (19,55) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
dataset
# Out:
#               id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 0        1077501    1296599     5000.0       5000.0           4975.0
# 1        1077430    1314167     2500.0       2500.0           2500.0
# 2        1077175    1313524     2400.0       2400.0           2400.0
# 3        1076863    1277178    10000.0      10000.0          10000.0
# 4        1075358    1311748     3000.0       3000.0           3000.0
# ...          ...        ...        ...          ...              ...
# 887374  36371250   39102635    10000.0      10000.0          10000.0
# 887375  36441262   39152692    24000.0      24000.0          24000.0
# 887376  36271333   38982739    13000.0      13000.0          13000.0
# 887377  36490806   39222577    12000.0      12000.0          12000.0
# 887378  36271262   38982659    20000.0      20000.0          20000.0
#
#               term  int_rate  installment grade sub_grade  ... total_bal_il  \
# ...

# %%
dataset.shape
# Out:
# (887379, 74)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 887379 entries, 0 to 887378
# Data columns (total 74 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   id                           887379 non-null  int64
#  1   member_id                    887379 non-null  int64
#  2   loan_amnt                    887379 non-null  float64
#  3   funded_amnt                  887379 non-null  float64
#  4   funded_amnt_inv              887379 non-null  float64
#  5   term                         887379 non-null  object
#  6   int_rate                     887379 non-null  float64
#  7   installment                  887379 non-null  float64
#  8   grade                        887379 non-null  object
#  9   sub_grade                    887379 non-null  object
#  10  emp_title                    835917 non-null  object
#  11  emp_length                   842554 non-null  object
# ...

# %%
dataset.describe()
# Out:
#                  id     member_id      loan_amnt    funded_amnt  \
# count  8.873790e+05  8.873790e+05  887379.000000  887379.000000
# mean   3.246513e+07  3.500182e+07   14755.264605   14741.877625
# std    2.282734e+07  2.411335e+07    8435.455601    8429.897657
# min    5.473400e+04  7.047300e+04     500.000000     500.000000
# 25%    9.206643e+06  1.087713e+07    8000.000000    8000.000000
# 50%    3.443327e+07  3.709528e+07   13000.000000   13000.000000
# 75%    5.490814e+07  5.847135e+07   20000.000000   20000.000000
# max    6.861706e+07  7.354484e+07   35000.000000   35000.000000
#
#        funded_amnt_inv       int_rate    installment    annual_inc  \
# count    887379.000000  887379.000000  887379.000000  8.873750e+05
# mean      14702.464383      13.246740     436.717127  7.502759e+04
# std        8442.106732       4.381867     244.186593  6.469830e+04
# min           0.000000       5.320000      15.670000  0.000000e+00
# ...

# %%
pd.crosstab(dataset['verification_status'], dataset['loan_status'], margins = True)
# Out:
# loan_status          Charged Off  Current  Default  \
# verification_status
# Not Verified               12208   171400      278
# Source Verified            13740   243705      462
# Verified                   19300   186674      479
# All                        45248   601779     1219
#
# loan_status          Does not meet the credit policy. Status:Charged Off  \
# verification_status
# Not Verified                                                       511
# Source Verified                                                     82
# Verified                                                           168
# All                                                                761
#
# loan_status          Does not meet the credit policy. Status:Fully Paid  \
# verification_status
# Not Verified                                                      1321
# Source Verified                                                    208
# ...

# %%
loan_verification = pd.crosstab(dataset['verification_status'], dataset['loan_status'], margins = True)

# %%
loan_verification['%_Loan_Verification'] = (loan_verification.Issued/loan_verification.All)* 100

# %%
loan_verification
# Out:
# loan_status          Charged Off  Current  Default  \
# verification_status
# Not Verified               12208   171400      278
# Source Verified            13740   243705      462
# Verified                   19300   186674      479
# All                        45248   601779     1219
#
# loan_status          Does not meet the credit policy. Status:Charged Off  \
# verification_status
# Not Verified                                                       511
# Source Verified                                                     82
# Verified                                                           168
# All                                                                761
#
# loan_status          Does not meet the credit policy. Status:Fully Paid  \
# verification_status
# Not Verified                                                      1321
# Source Verified                                                    208
# ...

# %%
pd.crosstab(dataset['pymnt_plan'], dataset['loan_status'], margins = True).head()
# Out:
# loan_status  Charged Off  Current  Default  \
# pymnt_plan
# n                  45248   601776     1219
# y                      0        3        0
# All                45248   601779     1219
#
# loan_status  Does not meet the credit policy. Status:Charged Off  \
# pymnt_plan
# n                                                          761
# y                                                            0
# All                                                        761
#
# loan_status  Does not meet the credit policy. Status:Fully Paid  Fully Paid  \
# pymnt_plan
# n                                                         1988       207721
# y                                                            0            2
# All                                                       1988       207723
#
# loan_status  In Grace Period  Issued  Late (16-30 days)  Late (31-120 days)  \
# pymnt_plan
# n                       6253    8460               2356               11587
# ...

# %%
dataset.boxplot(column = 'loan_amnt')
# Out:
# <AxesSubplot:>

# %%
dataset['loan_amnt'].hist(bins=20)
# Out:
# <AxesSubplot:>

# %%
dataset.boxplot(column = 'annual_inc')
# Out:
# <AxesSubplot:>

# %%
dataset['annual_inc'].hist(bins=20)
# Out:
# <AxesSubplot:>

# %%
dataset.isnull().sum().iloc[:50]
# Out:
# id                                 0
# member_id                          0
# loan_amnt                          0
# funded_amnt                        0
# funded_amnt_inv                    0
# term                               0
# int_rate                           0
# installment                        0
# grade                              0
# sub_grade                          0
# emp_title                      51462
# emp_length                     44825
# home_ownership                     0
# annual_inc                         4
# verification_status                0
# issue_d                            0
# loan_status                        0
# pymnt_plan                         0
# url                                0
# desc                          761351
# purpose                            0
# title                            152
# zip_code                           0
# addr_state                         0
# dti                                0
# ...

# %%
dataset.isnull().sum().iloc[50:74]
# Out:
# mths_since_last_major_derog    665676
# policy_code                         0
# application_type                    0
# annual_inc_joint               886868
# dti_joint                      886870
# verification_status_joint      886868
# acc_now_delinq                     29
# tot_coll_amt                    70276
# tot_cur_bal                     70276
# open_acc_6m                    866007
# open_il_6m                     866007
# open_il_12m                    866007
# open_il_24m                    866007
# mths_since_rcnt_il             866569
# total_bal_il                   866007
# il_util                        868762
# open_rv_12m                    866007
# open_rv_24m                    866007
# max_bal_bc                     866007
# all_util                       866007
# total_rev_hi_lim                70276
# inq_fi                         866007
# total_cu_tl                    866007
# inq_last_12m                   866007
# dtype: int64

# %%
df_dataset = pd.DataFrame(dataset)

# %%
df_dataset.drop(columns= ['inq_last_12m', 'total_cu_tl', 'inq_fi', 'total_rev_hi_lim', 'all_util', 'max_bal_bc', 'open_rv_24m','open_rv_12m', 'il_util', 'total_bal_il', 'mths_since_rcnt_il', 'open_il_24m', 'open_il_12m', 'open_il_6m', 'open_acc_6m', 'tot_cur_bal', 'tot_coll_amt', 'verification_status_joint', 'dti_joint', 'annual_inc_joint', 'mths_since_last_major_derog', 'mths_since_last_record','last_pymnt_d','next_pymnt_d', 'mths_since_last_delinq', 'desc', 'emp_length', 'emp_title'], axis = 1, inplace = True)

# %%
len(df_dataset.columns)
# Out:
# 46

# %%
df_dataset
# Out:
#               id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 0        1077501    1296599     5000.0       5000.0           4975.0
# 1        1077430    1314167     2500.0       2500.0           2500.0
# 2        1077175    1313524     2400.0       2400.0           2400.0
# 3        1076863    1277178    10000.0      10000.0          10000.0
# 4        1075358    1311748     3000.0       3000.0           3000.0
# ...          ...        ...        ...          ...              ...
# 887374  36371250   39102635    10000.0      10000.0          10000.0
# 887375  36441262   39152692    24000.0      24000.0          24000.0
# 887376  36271333   38982739    13000.0      13000.0          13000.0
# 887377  36490806   39222577    12000.0      12000.0          12000.0
# 887378  36271262   38982659    20000.0      20000.0          20000.0
#
#               term  int_rate  installment grade sub_grade  ... total_rec_int  \
# ...

# %%
df_dataset.isnull().sum()
# Out:
# id                              0
# member_id                       0
# loan_amnt                       0
# funded_amnt                     0
# funded_amnt_inv                 0
# term                            0
# int_rate                        0
# installment                     0
# grade                           0
# sub_grade                       0
# home_ownership                  0
# annual_inc                      4
# verification_status             0
# issue_d                         0
# loan_status                     0
# pymnt_plan                      0
# url                             0
# purpose                         0
# title                         152
# zip_code                        0
# addr_state                      0
# dti                             0
# delinq_2yrs                    29
# earliest_cr_line               29
# inq_last_6mths                 29
# open_acc                       29
# pub_rec                        29
# ...

# %%
df_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 887379 entries, 0 to 887378
# Data columns (total 46 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   id                          887379 non-null  int64
#  1   member_id                   887379 non-null  int64
#  2   loan_amnt                   887379 non-null  float64
#  3   funded_amnt                 887379 non-null  float64
#  4   funded_amnt_inv             887379 non-null  float64
#  5   term                        887379 non-null  object
#  6   int_rate                    887379 non-null  float64
#  7   installment                 887379 non-null  float64
#  8   grade                       887379 non-null  object
#  9   sub_grade                   887379 non-null  object
#  10  home_ownership              887379 non-null  object
#  11  annual_inc                  887375 non-null  float64
# ...

# %%
df_dataset['annual_inc'].fillna(df_dataset['annual_inc'].mean(), inplace = True)

# %%
df_dataset['title'].fillna(df_dataset['title'].mode()[0], inplace = True)

# %%
df_dataset['delinq_2yrs'].fillna(df_dataset['delinq_2yrs'].mean(), inplace = True)

# %%
df_dataset['earliest_cr_line'].fillna(df_dataset['earliest_cr_line'].mode()[0], inplace = True)

# %%
df_dataset['inq_last_6mths'].fillna(df_dataset['inq_last_6mths'].mean(), inplace = True)

# %%
df_dataset['open_acc'].fillna(df_dataset['open_acc'].mean(), inplace = True)

# %%
df_dataset['pub_rec'].fillna(df_dataset['pub_rec'].mean(), inplace = True)

# %%
df_dataset['revol_util'].fillna(df_dataset['revol_util'].mean(), inplace = True)

# %%
df_dataset['total_acc'].fillna(df_dataset['total_acc'].mean(), inplace = True)

# %%
df_dataset['last_credit_pull_d'].fillna(df_dataset['last_credit_pull_d'].mode()[0], inplace = True)

# %%
df_dataset['collections_12_mths_ex_med'].fillna(df_dataset['collections_12_mths_ex_med'].mean(), inplace = True)

# %%
df_dataset['acc_now_delinq'].fillna(df_dataset['acc_now_delinq'].mean(), inplace = True)

# %%
df_dataset.isnull().sum()
# Out:
# id                            0
# member_id                     0
# loan_amnt                     0
# funded_amnt                   0
# funded_amnt_inv               0
# term                          0
# int_rate                      0
# installment                   0
# grade                         0
# sub_grade                     0
# home_ownership                0
# annual_inc                    0
# verification_status           0
# issue_d                       0
# loan_status                   0
# pymnt_plan                    0
# url                           0
# purpose                       0
# title                         0
# zip_code                      0
# addr_state                    0
# dti                           0
# delinq_2yrs                   0
# earliest_cr_line              0
# inq_last_6mths                0
# open_acc                      0
# pub_rec                       0
# revol_bal                     0
# revol_util                    0
# ...

# %%
pd.crosstab(dataset['application_type'], dataset['loan_status'], margins = True)
# Out:
# loan_status       Charged Off  Current  Default  \
# application_type
# INDIVIDUAL              45248   601338     1219
# JOINT                       0      441        0
# All                     45248   601779     1219
#
# loan_status       Does not meet the credit policy. Status:Charged Off  \
# application_type
# INDIVIDUAL                                                      761
# JOINT                                                             0
# All                                                             761
#
# loan_status       Does not meet the credit policy. Status:Fully Paid  \
# application_type
# INDIVIDUAL                                                     1988
# JOINT                                                             0
# All                                                            1988
#
# loan_status       Fully Paid  In Grace Period  Issued  Late (16-30 days)  \
# application_type
# ...

# %%
pd.crosstab(dataset['total_acc'], dataset['loan_status'], margins = True)
# Out:
# loan_status  Charged Off  Current  Default  \
# total_acc
# 1.0                    0        0        0
# 2.0                    4        9        0
# 3.0                   73      105        0
# 4.0                  209     1761        6
# 5.0                  299     2970        4
# ...                  ...      ...      ...
# 151.0                  0        1        0
# 156.0                  0        1        0
# 162.0                  0        1        0
# 169.0                  0        1        0
# All                45248   601779     1219
#
# loan_status  Does not meet the credit policy. Status:Charged Off  \
# total_acc
# 1.0                                                          4
# 2.0                                                         11
# 3.0                                                         15
# 4.0                                                         15
# 5.0                                                         21
# ...

# %%
pd.crosstab(dataset['home_ownership'], dataset['loan_status'], margins = True)
# Out:
# loan_status     Charged Off  Current  Default  \
# home_ownership
# ANY                       0        2        0
# MORTGAGE              19878   303764      498
# NONE                      7        2        0
# OTHER                    27        3        0
# OWN                    4025    62041      110
# RENT                  21311   235967      611
# All                   45248   601779     1219
#
# loan_status     Does not meet the credit policy. Status:Charged Off  \
# home_ownership
# ANY                                                             0
# MORTGAGE                                                      348
# NONE                                                            1
# OTHER                                                          11
# OWN                                                            49
# RENT                                                          352
# All                                                           761
#
# ...

# %%
pd.crosstab(dataset['collection_recovery_fee'], dataset['loan_status'], margins = True)
# Out:
# loan_status              Charged Off  Current  Default  \
# collection_recovery_fee
# 0.0                            22213   601779     1219
# 0.036                              1        0        0
# 0.0449999999                       0        0        0
# 0.063                              1        0        0
# 0.0710999972                       1        0        0
# ...                              ...      ...      ...
# 5774.8                             1        0        0
# 6543.04                            1        0        0
# 6972.59                            1        0        0
# 7002.19                            1        0        0
# All                            45248   601779     1219
#
# loan_status              Does not meet the credit policy. Status:Charged Off  \
# collection_recovery_fee
# 0.0                                                                    289
# 0.036                                                                    0
# ...

# %%
pd.crosstab(dataset['total_rec_int'], dataset['loan_status'], margins = True)
# Out:
# loan_status    Charged Off  Current  Default  \
# total_rec_int
# 0.0                    531     8804        9
# 0.01                     0        0        0
# 0.39                     0        0        0
# 0.56                     0        0        0
# 0.59                     0        0        0
# ...                    ...      ...      ...
# 23171.65                 0        1        0
# 23172.31                 0        1        0
# 23450.38                 0        1        0
# 24205.62                 0        1        0
# All                  45248   601779     1219
#
# loan_status    Does not meet the credit policy. Status:Charged Off  \
# total_rec_int
# 0.0                                                           12
# 0.01                                                           0
# 0.39                                                           0
# 0.56                                                           0
# ...

# %%
pd.crosstab(dataset['purpose'], dataset['loan_status'], margins = True)
# Out:
# loan_status         Charged Off  Current  Default  \
# purpose
# car                         448     4937       10
# credit_card                7826   149835      233
# debt_consolidation        27599   356239      790
# educational                  56        1        0
# home_improvement           2269    34980       47
# house                       286     1854        7
# major_purchase              874    10308       14
# medical                     569     5324       15
# moving                      425     3121       11
# other                      2936    26607       65
# renewable_energy             54      282        0
# small_business             1371     5020       19
# vacation                    270     2946        8
# wedding                     265      325        0
# All                       45248   601779     1219
#
# loan_status         Does not meet the credit policy. Status:Charged Off  \
# purpose
# ...

# %%
purpose_loan = pd.crosstab(dataset['purpose'], dataset['loan_status'], margins = True)

# %%
purpose_loan['Per_purpose_loan'] = (purpose_loan.Issued/purpose_loan.All)*100

# %%
purpose_loan
# Out:
# loan_status         Charged Off  Current  Default  \
# purpose
# car                         448     4937       10
# credit_card                7826   149835      233
# debt_consolidation        27599   356239      790
# educational                  56        1        0
# home_improvement           2269    34980       47
# house                       286     1854        7
# major_purchase              874    10308       14
# medical                     569     5324       15
# moving                      425     3121       11
# other                      2936    26607       65
# renewable_energy             54      282        0
# small_business             1371     5020       19
# vacation                    270     2946        8
# wedding                     265      325        0
# All                       45248   601779     1219
#
# loan_status         Does not meet the credit policy. Status:Charged Off  \
# purpose
# ...

# %%
pd.crosstab(dataset['addr_state'], dataset['loan_status'], margins = True).head()
# Out:
# loan_status  Charged Off  Current  Default  \
# addr_state
# AK                    96     1469        2
# AL                   662     7576        9
# AR                   337     4637        8
# AZ                  1049    13577       39
# CA                  7332    81851      211
#
# loan_status  Does not meet the credit policy. Status:Charged Off  \
# addr_state
# AK                                                           1
# AL                                                           8
# AR                                                           6
# AZ                                                          18
# CA                                                         101
#
# loan_status  Does not meet the credit policy. Status:Fully Paid  Fully Paid  \
# addr_state
# AK                                                           4          567
# AL                                                          24         2485
# ...

# %%
loan_state = pd.crosstab(dataset['addr_state'], dataset['loan_status'], margins = True)

# %%
loan_state['per_loan_state'] = (loan_state.Issued/loan_state.All)*100

# %%
loan_state
# Out:
# loan_status  Charged Off  Current  Default  \
# addr_state
# AK                    96     1469        2
# AL                   662     7576        9
# AR                   337     4637        8
# AZ                  1049    13577       39
# CA                  7332    81851      211
# CO                   784    12573       25
# CT                   614     9353        8
# DC                    87     1543        2
# DE                   121     1730        5
# FL                  3524    40999       95
# GA                  1360    19993       36
# HI                   276     2894        8
# IA                     1        1        0
# ID                     1        3        0
# IL                  1542    25098       28
# IN                   626    10529       19
# KS                   356     5605        5
# KY                   436     6016       15
# LA                   566     7216       18
# MA                  1017    13667       29
# ...

# %%
df_dataset.loan_amnt
# Out:
# 0          5000.0
# 1          2500.0
# 2          2400.0
# 3         10000.0
# 4          3000.0
#            ...
# 887374    10000.0
# 887375    24000.0
# 887376    13000.0
# 887377    12000.0
# 887378    20000.0
# Name: loan_amnt, Length: 887379, dtype: float64

# %%
described_purpose_amnt = df_dataset.groupby('purpose')['loan_amnt'].mean()

# %%
described_purpose_amnt
# Out:
# purpose
# car                    8882.432585
# credit_card           15338.833288
# debt_consolidation    15428.498565
# educational            6616.075650
# home_improvement      14320.934226
# house                 14798.104937
# major_purchase        11600.004341
# medical                9019.069087
# moving                 7891.572774
# other                  9889.356903
# renewable_energy       9948.304348
# small_business        15420.429797
# vacation               6289.537584
# wedding               10468.630166
# Name: loan_amnt, dtype: float64

# %%
df_dataset.groupby('purpose')['loan_amnt'].std()
# Out:
# purpose
# car                   6175.145513
# credit_card           8287.928747
# debt_consolidation    8282.199461
# educational           5093.890248
# home_improvement      8920.759613
# house                 8887.931847
# major_purchase        8608.059510
# medical               6845.686243
# moving                6338.935972
# other                 7512.399532
# renewable_energy      7586.272701
# small_business        9281.649871
# vacation              5206.062035
# wedding               6750.864293
# Name: loan_amnt, dtype: float64

# %%
df_dataset.groupby('purpose')['loan_amnt'].describe()
# Out:
#                        count          mean          std     min     25%  \
# purpose
# car                   8863.0   8882.432585  6175.145513  1000.0  4800.0
# credit_card         206182.0  15338.833288  8287.928747   500.0  9000.0
# debt_consolidation  524215.0  15428.498565  8282.199461   700.0  9350.0
# educational            423.0   6616.075650  5093.890248   500.0  3000.0
# home_improvement     51829.0  14320.934226  8920.759613   900.0  7000.0
# house                 3707.0  14798.104937  8887.931847  1000.0  8000.0
# major_purchase       17277.0  11600.004341  8608.059510  1000.0  5000.0
# medical               8540.0   9019.069087  6845.686243   500.0  4000.0
# moving                5414.0   7891.572774  6338.935972   800.0  3500.0
# other                42894.0   9889.356903  7512.399532   500.0  4450.0
# renewable_energy       575.0   9948.304348  7586.272701  1000.0  4000.0
# small_business       10377.0  15420.429797  9281.649871   500.0  8000.0
# ...

# %%
df_dataset.boxplot(column = 'loan_amnt', by = 'purpose')
# Out:
# <AxesSubplot:title={'center':'loan_amnt'}, xlabel='purpose'>

# %%
df_dataset.boxplot(column = 'dti')
# Out:
# <AxesSubplot:>

# %%
df_dataset['dti'].hist(bins=20)
# Out:
# <AxesSubplot:>

# %%
df_dataset.boxplot(column = 'last_pymnt_amnt')
# Out:
# <AxesSubplot:>

# %%
df_dataset['last_pymnt_amnt'].hist(bins=20)
# Out:
# <AxesSubplot:>

# %%
df_dataset['last_pymnt_amnt'].describe()
# Out:
# count    887379.000000
# mean       2164.145585
# std        4794.783233
# min           0.000000
# 25%         280.170000
# 50%         462.780000
# 75%         831.245000
# max       36475.590000
# Name: last_pymnt_amnt, dtype: float64

# %%
df_dataset.boxplot(column = 'recoveries')
# Out:
# <AxesSubplot:>

# %%
df_dataset['recoveries'].hist(bins=20)
# Out:
# <AxesSubplot:>

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
Normalization = MinMaxScaler()

data = df_dataset[['loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'int_rate', 'installment', 'annual_inc', 'dti', 'delinq_2yrs', 'inq_last_6mths', 'open_acc', 'pub_rec', 'revol_bal', 'revol_util', 'total_acc', 'out_prncp', 'out_prncp_inv', 'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int', 'total_rec_late_fee', 'recoveries', 'collection_recovery_fee', 'last_pymnt_amnt', 'collections_12_mths_ex_med', 'policy_code', 'acc_now_delinq']]
Normalization.fit_transform(data)
# Out:
# array([[0.13043478, 0.13043478, 0.14214286, ..., 0.        , 0.        ,
#         0.        ],
#        [0.05797101, 0.05797101, 0.07142857, ..., 0.        , 0.        ,
#         0.        ],
#        [0.05507246, 0.05507246, 0.06857143, ..., 0.        , 0.        ,
#         0.        ],
#        ...,
#        [0.36231884, 0.36231884, 0.37142857, ..., 0.        , 0.        ,
#         0.        ],
#        [0.33333333, 0.33333333, 0.34285714, ..., 0.05      , 0.        ,
#         0.        ],
#        [0.56521739, 0.56521739, 0.57142857, ..., 0.        , 0.        ,
#         0.        ]])

# %%
import joblib

# %%
joblib.dump(df_dataset, 'lydia_send_this_to_tiago.pickle')
# Out:
# ['lydia_send_this_to_tiago.pickle']

# %%
all_the_infinites = df_dataset.applymap(lambda x: np.isinf(x) if pd.api.types.is_number(x) else False)
all_the_infinites.value_counts()
# Out:
# id     member_id  loan_amnt  funded_amnt  funded_amnt_inv  term   int_rate  installment  grade  sub_grade  home_ownership  annual_inc  verification_status  issue_d  loan_status  pymnt_plan  url    purpose  title  zip_code  addr_state  dti    delinq_2yrs  earliest_cr_line  inq_last_6mths  open_acc  pub_rec  revol_bal  revol_util  total_acc  initial_list_status  out_prncp  out_prncp_inv  total_pymnt  total_pymnt_inv  total_rec_prncp  total_rec_int  total_rec_late_fee  recoveries  collection_recovery_fee  last_pymnt_amnt  last_credit_pull_d  collections_12_mths_ex_med  policy_code  application_type  acc_now_delinq
# ...

# %%
for col in all_the_infinites.columns:
  if all_the_infinites[col].sum() > 0:
    print(col)

# %%
df_dataset.drop(columns = ['total_pymnt', 'last_pymnt_amnt_log'], axis = 1, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23844/1086613863.py in <module>
# ----> 1 df_dataset.drop(columns = ['total_pymnt', 'last_pymnt_amnt_log'], axis = 1, inplace = True)
#
# ~\anaconda3\envs\newenv\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\envs\newenv\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ...

# %%
len(df_dataset.columns)
# Out:
# 46

# %%
df_dataset.head()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599     5000.0       5000.0           4975.0   36 months
# 1  1077430    1314167     2500.0       2500.0           2500.0   60 months
# 2  1077175    1313524     2400.0       2400.0           2400.0   36 months
# 3  1076863    1277178    10000.0      10000.0          10000.0   36 months
# 4  1075358    1311748     3000.0       3000.0           3000.0   60 months
#
#    int_rate  installment grade sub_grade  ... total_rec_int  \
# 0     10.65       162.87     B        B2  ...        861.07
# 1     15.27        59.83     C        C4  ...        435.17
# 2     15.96        84.33     C        C5  ...        603.65
# 3     13.49       339.31     C        C1  ...       2209.33
# 4     12.69        67.79     B        B5  ...       1009.07
#
#    total_rec_late_fee recoveries collection_recovery_fee last_pymnt_amnt  \
# 0                0.00       0.00                    0.00          171.62
# ...

# %%
df_dataset.drop(columns = ['grade', 'sub_grade', 'collections_12_mths_ex_med'], axis = 1, inplace = True)

# %%
df_dataset['loan_status'].value_counts()
# Out:
# Current                                                601779
# Fully Paid                                             207723
# Charged Off                                             45248
# Late (31-120 days)                                      11591
# Issued                                                   8460
# In Grace Period                                          6253
# Late (16-30 days)                                        2357
# Does not meet the credit policy. Status:Fully Paid       1988
# Default                                                  1219
# Does not meet the credit policy. Status:Charged Off       761
# Name: loan_status, dtype: int64

# %%
df_without_currents = df_dataset[df_dataset['loan_status']!='Current'].copy()

# %%
df_without_currents['loan_status'].value_counts()
# Out:
# Fully Paid                                             207723
# Charged Off                                             45248
# Late (31-120 days)                                      11591
# Issued                                                   8460
# In Grace Period                                          6253
# Late (16-30 days)                                        2357
# Does not meet the credit policy. Status:Fully Paid       1988
# Default                                                  1219
# Does not meet the credit policy. Status:Charged Off       761
# Name: loan_status, dtype: int64

# %%
df_without_Issued = df_without_currents[df_without_currents['loan_status']!='Issued'].copy()

# %%
df_without_Issued['loan_status'].value_counts()
# Out:
# Fully Paid                                             207723
# Charged Off                                             45248
# Late (31-120 days)                                      11591
# In Grace Period                                          6253
# Late (16-30 days)                                        2357
# Does not meet the credit policy. Status:Fully Paid       1988
# Default                                                  1219
# Does not meet the credit policy. Status:Charged Off       761
# Name: loan_status, dtype: int64

# %%
df = df_without_Issued[df_without_Issued['loan_status']!='In Grace Period'].copy()

# %%
df
# Out:
#               id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 0        1077501    1296599     5000.0       5000.0           4975.0
# 1        1077430    1314167     2500.0       2500.0           2500.0
# 2        1077175    1313524     2400.0       2400.0           2400.0
# 3        1076863    1277178    10000.0      10000.0          10000.0
# 5        1075269    1311441     5000.0       5000.0           5000.0
# ...          ...        ...        ...          ...              ...
# 887351  36743377   39486112     4200.0       4200.0           4200.0
# 887364  36231718   38943165    10775.0      10775.0          10775.0
# 887366  36241316   38952731     6225.0       6225.0           6225.0
# 887369  36421485   39142898     4000.0       4000.0           4000.0
# 887371  36260758   38972123    10850.0      10850.0          10850.0
#
#               term  int_rate  installment home_ownership  annual_inc  ...  \
# ...

# %%
df['loan_status'].value_counts()
# Out:
# Fully Paid                                             207723
# Charged Off                                             45248
# Late (31-120 days)                                      11591
# Late (16-30 days)                                        2357
# Does not meet the credit policy. Status:Fully Paid       1988
# Default                                                  1219
# Does not meet the credit policy. Status:Charged Off       761
# Name: loan_status, dtype: int64

# %%
def gimme_0_or_1(value):
    if value == 'Fully Paid' or value == 'Does not meet the credit policy. Status:Fully Paid':
        return 1
    else:
        return 0

# %%
df['y'] = df['loan_status'].apply(gimme_0_or_1)

# %%
df
# Out:
#               id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 0        1077501    1296599     5000.0       5000.0           4975.0
# 1        1077430    1314167     2500.0       2500.0           2500.0
# 2        1077175    1313524     2400.0       2400.0           2400.0
# 3        1076863    1277178    10000.0      10000.0          10000.0
# 5        1075269    1311441     5000.0       5000.0           5000.0
# ...          ...        ...        ...          ...              ...
# 887351  36743377   39486112     4200.0       4200.0           4200.0
# 887364  36231718   38943165    10775.0      10775.0          10775.0
# 887366  36241316   38952731     6225.0       6225.0           6225.0
# 887369  36421485   39142898     4000.0       4000.0           4000.0
# 887371  36260758   38972123    10850.0      10850.0          10850.0
#
#               term  int_rate  installment home_ownership  annual_inc  ...  \
# ...

# %%
df.dtypes
# Out:
# id                           int64
# member_id                    int64
# loan_amnt                  float64
# funded_amnt                float64
# funded_amnt_inv            float64
# term                        object
# int_rate                   float64
# installment                float64
# home_ownership              object
# annual_inc                 float64
# verification_status         object
# issue_d                     object
# loan_status                 object
# pymnt_plan                  object
# url                         object
# purpose                     object
# title                       object
# zip_code                    object
# addr_state                  object
# dti                        float64
# delinq_2yrs                float64
# earliest_cr_line            object
# inq_last_6mths             float64
# open_acc                   float64
# pub_rec                    float64
# revol_bal                  float64
# revol_util                 float64
# ...

# %%
df_numerical = df.drop(columns = ['application_type', 'last_credit_pull_d', 'initial_list_status', 'earliest_cr_line',
                                  'addr_state', 'zip_code', 'title', 'purpose', 'url','pymnt_plan', 'loan_status',
                                  'issue_d', 'verification_status', 'home_ownership', 'term'])

# %%
df2 = df_numerical.set_index('id')

# %%
df2
# Out:
#           member_id  loan_amnt  funded_amnt  funded_amnt_inv  int_rate  \
# id
# 1077501     1296599     5000.0       5000.0           4975.0     10.65
# 1077430     1314167     2500.0       2500.0           2500.0     15.27
# 1077175     1313524     2400.0       2400.0           2400.0     15.96
# 1076863     1277178    10000.0      10000.0          10000.0     13.49
# 1075269     1311441     5000.0       5000.0           5000.0      7.90
# ...             ...        ...          ...              ...       ...
# 36743377   39486112     4200.0       4200.0           4200.0     15.99
# 36231718   38943165    10775.0      10775.0          10775.0      6.03
# 36241316   38952731     6225.0       6225.0           6225.0     16.49
# 36421485   39142898     4000.0       4000.0           4000.0      8.67
# 36260758   38972123    10850.0      10850.0          10850.0     19.24
#
#           installment  annual_inc    dti  delinq_2yrs  inq_last_6mths  ...  \
# ...

# %%
X = df2.drop('y', axis = 1).copy()
X.head()
# Out:
#          member_id  loan_amnt  funded_amnt  funded_amnt_inv  int_rate  \
# id
# 1077501    1296599     5000.0       5000.0           4975.0     10.65
# 1077430    1314167     2500.0       2500.0           2500.0     15.27
# 1077175    1313524     2400.0       2400.0           2400.0     15.96
# 1076863    1277178    10000.0      10000.0          10000.0     13.49
# 1075269    1311441     5000.0       5000.0           5000.0      7.90
#
#          installment  annual_inc    dti  delinq_2yrs  inq_last_6mths  ...  \
# id                                                                    ...
# 1077501       162.87     24000.0  27.65          0.0             1.0  ...
# 1077430        59.83     30000.0   1.00          0.0             5.0  ...
# 1077175        84.33     12252.0   8.72          0.0             2.0  ...
# 1076863       339.31     49200.0  20.00          0.0             1.0  ...
# 1075269       156.46     36000.0  11.20          0.0             3.0  ...
#
# ...

# %%
y = df2['y'].copy()

# %%
y.head()
# Out:
# id
# 1077501    1
# 1077430    0
# 1077175    1
# 1076863    1
# 1075269    1
# Name: y, dtype: int64

# %%
y.value_counts()
# Out:
# 1    209711
# 0     61176
# Name: y, dtype: int64

# %%
# spliting the data into training and testing sets

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)
X_train.iloc[:,15:27]
# Out:
#           out_prncp  out_prncp_inv   total_pymnt  total_pymnt_inv  \
# id
# 38098517        0.0            0.0  25200.430000         25200.43
# 10696094        0.0            0.0  26502.520000         26502.52
# 19205959        0.0            0.0  34001.920000         34001.92
# 3352083         0.0            0.0   2606.780000          2606.78
# 40521372        0.0            0.0   2816.540000          2816.54
# ...             ...            ...           ...              ...
# 15340587        0.0            0.0  14620.290000         14620.29
# 5197396         0.0            0.0  13322.690000         13322.69
# 1854698         0.0            0.0  25676.690000         25676.69
# 1267560         0.0            0.0   4854.614384          4854.61
# 2308339         0.0            0.0  22922.794948         22922.79
#
#           total_rec_prncp  total_rec_int  total_rec_late_fee  recoveries  \
# id
# 38098517         25000.00         200.43                 0.0         0.0
# ...

# %%
X_train['delinq_2yrs'].unique()
# Out:
# array([ 0.        ,  1.        ,  2.        ,  3.        , 10.        ,
#         6.        ,  4.        ,  5.        ,  7.        , 11.        ,
#         8.        , 12.        , 13.        ,  9.        ,  0.31444188,
#        15.        , 14.        , 18.        , 29.        , 17.        ,
#        19.        , 20.        , 22.        , 21.        ])

# %%
X_train['policy_code'].unique()
# Out:
# array([1.])

# %%
X_train['acc_now_delinq'].unique()
# Out:
# array([0.00000000e+00, 1.00000000e+00, 3.00000000e+00, 2.00000000e+00,
#        4.99126613e-03, 5.00000000e+00])

# %%
X_train['pub_rec'].unique()
# Out:
# array([ 0.        ,  1.        ,  5.        ,  2.        ,  4.        ,
#         3.        ,  9.        ,  6.        ,  7.        ,  8.        ,
#         0.19530738, 10.        , 11.        , 12.        , 15.        ])

# %%
X_train['out_prncp'].unique()
# Out:
# array([   0.  , 5957.39, 5248.84, ...,  655.94, 4097.92, 3809.88])

# %%
#Applying Algorithms
#1. DecisionTreeClassifier

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix

# %%
dt = DecisionTreeClassifier(criterion = 'entropy', random_state = 42)
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=42)

# %%
pd.Series?

# %%
pd.Series(dt.feature_importances_, index=X_train.columns).sort_values(ascending=False)
# Out:
# last_pymnt_amnt            0.462945
# member_id                  0.148734
# recoveries                 0.133704
# total_rec_prncp            0.107620
# funded_amnt                0.082738
# out_prncp_inv              0.023829
# out_prncp                  0.011386
# total_rec_late_fee         0.006812
# loan_amnt                  0.006555
# total_rec_int              0.005864
# funded_amnt_inv            0.003431
# installment                0.002687
# total_pymnt                0.000780
# int_rate                   0.000700
# dti                        0.000617
# revol_bal                  0.000442
# annual_inc                 0.000303
# total_acc                  0.000269
# total_pymnt_inv            0.000185
# open_acc                   0.000183
# revol_util                 0.000096
# inq_last_6mths             0.000077
# delinq_2yrs                0.000042
# pub_rec                    0.000000
# collection_recovery_fee    0.000000
# policy_code                0.000000
# ...

# %%
y_pred = dt.predict(X_test)
y_pred
# Out:
# array([1, 1, 1, ..., 1, 1, 1], dtype=int64)

# %%
from sklearn import metrics
print('The accuracy of decisionTree is:', metrics.accuracy_score( y_test, y_pred))
# Out:
# The accuracy of decisionTree is: 0.9996308464690464

# %%
metrics.accuracy_score?

# %%
metrics.confusion_matrix(y_test, y_pred)
# Out:
# array([[12170,    10],
#        [   10, 41988]], dtype=int64)

# %%
#2. Naive_Bayes

# %%
from sklearn.naive_bayes import GaussianNB
NBclf = GaussianNB()
NBclf.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
y1_pred = NBclf.predict(X_test)
y1_pred
# Out:
# array([1, 0, 1, ..., 1, 1, 1], dtype=int64)

# %%
print('The accuracy of Naive_bayes is:', metrics.accuracy_score(y_test, y1_pred))
# Out:
# The accuracy of Naive_bayes is: 0.8776071468123593

# %%
#3.RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier
Rfclf = RandomForestClassifier(max_depth=3, random_state= 42, n_estimators = 200, class_weight={0: 3, 1:1})
Rfclf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(class_weight={0: 3, 1: 1}, max_depth=3, n_estimators=200,
#                        random_state=42)

# %%
y2_pred = Rfclf.predict(X_test)
y2_pred
# Out:
# array([1, 1, 1, ..., 0, 1, 1], dtype=int64)

# %%
print('The accurcy of RandomForestClassifier is:', metrics.accuracy_score(y_test, y2_pred))
# Out:
# The accurcy of RandomForestClassifier is: 0.960500572187973

# %%
metrics.confusion_matrix(y_test, y2_pred)
# Out:
# array([[11509,   671],
#        [ 1469, 40529]], dtype=int64)

# %%
RandomForestClassifier?

# %%
pd.concat((X_train, X_test), ignore_index=True).drop_duplicates()
# Out:
#         member_id  loan_amnt  funded_amnt  funded_amnt_inv  int_rate  \
# 0        40861256    25000.0      25000.0          25000.0     19.24
# 1        12588189    24000.0      24000.0          24000.0      7.62
# 2        21408699    29250.0      29250.0          29250.0     17.57
# 3         4155031     7350.0       7350.0           7350.0     10.16
# 4        43386133    31975.0      31975.0          31975.0     25.83
# ...           ...        ...          ...              ...       ...
# 270882    7848047    18200.0      18200.0          18200.0     13.05
# 270883    8198019    35000.0      35000.0          35000.0     15.88
# 270884     807892     3000.0       3000.0           3000.0     14.46
# 270885   16672478     8750.0       8750.0           8750.0     20.49
# 270886   15459180    35000.0      35000.0          35000.0     14.16
#
#         installment  annual_inc    dti  delinq_2yrs  inq_last_6mths  ...  \
# ...
